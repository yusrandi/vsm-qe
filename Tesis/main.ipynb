# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from collections import OrderedDict

from importtxt import ImportTxt
from queryexpansion import QueryExpansion
from praprocessing import PraProcessing
from tfidf import TfIdf
from vsm import VectorSpaceModel

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()
stopwords_factory = StopWordRemoverFactory()
stopwords = stopwords_factory.get_stop_words()

impor = ImportTxt()
queryExpansion = QueryExpansion()
praProcess = PraProcessing()
tfIdf = TfIdf()
vSM = VectorSpaceModel()

# %%
kata_kunci = "dampak pandemi terhadap pengusaha, pariwisata, hotel, serta mall"

kata_kunci = queryExpansion.stateForQueryExpansion(kata_kunci)
print('QE Kata Kunci ', kata_kunci)

words = []
for word in kata_kunci.split(" "):
            stemmed_word = stemmer.stem(word)
            if word not in stopwords and stemmed_word not in words:
                if word != '':
                    words.append(stemmed_word)

print('words ', words)

path = '../data/*.txt'
docs = impor.export_from_txt(path, kata_kunci)
print("\nDocument Length : ", len(docs))

list_of_word = praProcess.get_list_of_word(docs)
print('list of word ', len(list_of_word))

print("=====================================TFIDF=====================================")
term_frequency = tfIdf.create_term_frequency(list_of_word, len(docs))
for index, sentence in enumerate(docs.values()):
    for word in stemmer.stem(sentence).split(" "):
        if word in term_frequency[index]:
            term_frequency[index][word] += 1
print('Term Frequency ', len(term_frequency))
# Out:
# words ['dampak', 'pandemi', 'terhadap', 'pengusaha,', 'pariwisata,', 'hotel,', 'serta', 'mall']
# QE Kata Kunci  pengusaha, juragan produser saudagar usahawan wiraswasta wirausaha dampak akibat buah buntut efek ekor ekses hasil imbas impak impresi konsekuensi pengaruh resultan benturan hantaman tumbukan terhadap pandemi endemi epidemi hawar pagebluk taun wabah serta bersama beserta dan dengan juga mall mercantile establishment outlet retail store sales outlet hotel, building edifice pariwisata, pelancongan turisme wisata
# words  ['usaha', 'juragan', 'produser', 'saudagar', 'usahawan', 'wiraswasta', 'wirausaha', 'dampak', 'akibat', 'buah', 'buntut', 'efek', 'ekor', 'ekses', 'hasil', 'imbas', 'impak', 'impresi', 'konsekuensi', 'pengaruh', 'resultan', 'bentur', 'hantam', 'tumbu', 'pandemi', 'endemi', 'epidemi', 'hawar', 'pagebluk', 'taun', 'wabah', 'sama', 'serta', 'mall', 'mercantile', 'establishment', 'outlet', 'retail', 'store', 'sales', 'hotel', 'building', 'edifice', 'pariwisata', 'lancong', 'turisme', 'wisata']
#
# Document Length :  409
# list of word  4670
# =====================================TFIDF=====================================
# Term Frequency  409

# %%
document_frequency = tfIdf.create_document_frequency(list_of_word)
for index, sentence in enumerate(term_frequency):
    if index > 0:
        for key, value in sentence.items():
            if value:
                document_frequency[key] += 1  
print('Document Frequency ', len(document_frequency))

d_df = tfIdf.get_d_df(len(docs)-1, document_frequency)
print('D / df ', len(d_df))

idf = tfIdf.get_idf(d_df)
print("Idf Log(df) ", len(idf)) 

w_q_t = tfIdf.get_w_q_t(term_frequency, idf)
print("TF-IDF atau Wqt ", len(w_q_t))
# Out:
# Document Frequency  4670
# D / df  4670
# Idf Log(df)  4670
# TF-IDF atau Wqt  409

# %%
print("=======================Vector Space Model=======================")

q_d = vSM.get_q_d(w_q_t)
# print("Q/D WQT dipangkatkn 2 dan diakar")

# for x in q_d:
    # print(x['total'])

sum_dj_q = vSM.get_dj_q(w_q_t)
# for x in sum_dj_q:
#     print(x['total'])

sum_qd = vSM.get_sum_of_qd(q_d)
# for x in sum_qd:
#     print(x['total'])

sim = vSM.get_sim(sum_dj_q, sum_qd)

kesimpulan = {}
i = 0
for x in docs.keys():
    if x != 'kata_kunci':
        kesimpulan[x] = sim[i]
    i += 1

sorted_value = OrderedDict(sorted(kesimpulan.items(), key=lambda x: x[1], reverse=True))

# print(sorted_value)
i = 1
for x in list(sorted_value):
    if kesimpulan[x] >= 0.1 :
        print(i, x, kesimpulan[x])
    i += 1
# Out:
# =======================Vector Space Model=======================
# Q/D WQT dipangkatkn 2 dan diakar
#
# Perhitungan Sum (tfidf * tfidf_query) atau dj.q
#
# Perhitungan |dj|.|q| (jarak dokumen * jarak query)
# Perhitungan dj.q / |dj|.|q|
# 1 perjalanan_84.txt 0.315
# 2 pengusaha_dan_bisnis_73.txt 0.312
# 3 pengusaha_dan_bisnis_5.txt 0.301
# 4 pengusaha_dan_bisnis_99.txt 0.295
# 5 pengusaha_dan_bisnis_81.txt 0.293
# 6 pengusaha_dan_bisnis_50.txt 0.28
# 7 pengusaha_dan_bisnis_18.txt 0.279
# 8 pengusaha_dan_bisnis_12.txt 0.271
# 9 guru_dan_siswa_48.txt 0.27
# 10 pengusaha_dan_bisnis_91.txt 0.27
# 11 pengusaha_dan_bisnis_7.txt 0.255
# 12 pengusaha_dan_bisnis_85.txt 0.252
# 13 pengusaha_dan_bisnis_15.txt 0.249
# 14 pengusaha_dan_bisnis_1.txt 0.249
# 15 pengusaha_dan_bisnis_75.txt 0.241
# 16 pengusaha_dan_bisnis_83.txt 0.239
# 17 tokoh_agama_dan_masyarakat_57.txt 0.238
# 18 pengusaha_dan_bisnis_82.txt 0.237
# 19 perjalanan_65.txt 0.235
# 20 pengusaha_dan_bisnis_65.txt 0.235
# 21 perjalanan_63.txt 0.228
# 22 guru_dan_siswa_4.txt 0.226
# 23 pengusaha_dan_bisnis_52.txt 0.221
# 24 pengusaha_dan_bisnis_32.txt 0.22
# 25 pengusaha_dan_bisnis_92.txt 0.219
# 26 perjalanan_64.txt 0.212
# 27 perjalanan_103.txt 0.212
# 28 pengusaha_dan_bisnis_34.txt 0.212
# 29 pengusaha_dan_bisnis_48.txt 0.211
# 30 ibu_dan_anak_57.txt 0.209
# 31 pengusaha_dan_bisnis_22.txt 0.209
# 32 pengusaha_dan_bisnis_93.txt 0.207
# 33 tokoh_agama_dan_masyarakat_61.txt 0.206
# 34 perjalanan_23.txt 0.205
# 35 perjalanan_58.txt 0.204
# 36 pengusaha_dan_bisnis_57.txt 0.203
# 37 pengusaha_dan_bisnis_42.txt 0.198
# 38 pengusaha_dan_bisnis_9.txt 0.191
# 39 tokoh_agama_dan_masyarakat_20.txt 0.191
# 40 guru_dan_siswa_39.txt 0.189
# 41 tokoh_agama_dan_masyarakat_38.txt 0.189
# 42 perjalanan_37.txt 0.189
# 43 pengusaha_dan_bisnis_78.txt 0.188
# 44 pengusaha_dan_bisnis_94.txt 0.187
# 45 pengusaha_dan_bisnis_87.txt 0.185
# 46 pengusaha_dan_bisnis_72.txt 0.183
# 47 pengusaha_dan_bisnis_11.txt 0.181
# 48 pengusaha_dan_bisnis_44.txt 0.18
# 49 pengusaha_dan_bisnis_56.txt 0.178
# 50 pengusaha_dan_bisnis_80.txt 0.178
# 51 guru_dan_siswa_10.txt 0.177
# 52 perjalanan_75.txt 0.177
# 53 perjalanan_15.txt 0.176
# 54 perjalanan_27.txt 0.176
# 55 perjalanan_68.txt 0.176
# 56 pengusaha_dan_bisnis_77.txt 0.175
# 57 guru_dan_siswa_17.txt 0.174
# 58 pengusaha_dan_bisnis_41.txt 0.174
# 59 pengusaha_dan_bisnis_4.txt 0.172
# 60 ibu_dan_anak_45.txt 0.172
# 61 tokoh_agama_dan_masyarakat_46.txt 0.171
# 62 pengusaha_dan_bisnis_61.txt 0.17
# 63 pengusaha_dan_bisnis_97.txt 0.169
# 64 perjalanan_2.txt 0.169
# 65 ibu_dan_anak_47.txt 0.167
# 66 pengusaha_dan_bisnis_68.txt 0.167
# 67 tokoh_agama_dan_masyarakat_35.txt 0.166
# 68 perjalanan_96.txt 0.165
# 69 perjalanan_32.txt 0.164
# 70 pengusaha_dan_bisnis_69.txt 0.164
# 71 pengusaha_dan_bisnis_35.txt 0.164
# 72 pengusaha_dan_bisnis_13.txt 0.163
# 73 pengusaha_dan_bisnis_39.txt 0.163
# 74 perjalanan_47.txt 0.163
# 75 tokoh_agama_dan_masyarakat_33.txt 0.163
# 76 tokoh_agama_dan_masyarakat_32.txt 0.162
# 77 perjalanan_73.txt 0.161
# 78 ibu_dan_anak_6.txt 0.16
# 79 guru_dan_siswa_25.txt 0.159
# 80 ibu_dan_anak_21.txt 0.157
# 81 pengusaha_dan_bisnis_37.txt 0.157
# 82 ibu_dan_anak_36.txt 0.156
# 83 pengusaha_dan_bisnis_40.txt 0.156
# 84 tokoh_agama_dan_masyarakat_2.txt 0.156
# 85 perjalanan_42.txt 0.156
# 86 perjalanan_33.txt 0.155
# 87 guru_dan_siswa_9.txt 0.154
# 88 ibu_dan_anak_56.txt 0.154
# 89 pengusaha_dan_bisnis_84.txt 0.154
# 90 perjalanan_79.txt 0.154
# 91 pengusaha_dan_bisnis_31.txt 0.154
# 92 ibu_dan_anak_28.txt 0.153
# 93 pengusaha_dan_bisnis_109.txt 0.152
# 94 ibu_dan_anak_18.txt 0.151
# 95 pengusaha_dan_bisnis_6.txt 0.149
# 96 pengusaha_dan_bisnis_49.txt 0.149
# 97 guru_dan_siswa_16.txt 0.148
# 98 tokoh_agama_dan_masyarakat_45.txt 0.148
# 99 perjalanan_13.txt 0.147
# 100 ibu_dan_anak_42.txt 0.144
# 101 perjalanan_71.txt 0.143
# 102 tokoh_agama_dan_masyarakat_64.txt 0.143
# 103 guru_dan_siswa_50.txt 0.143
# 104 ibu_dan_anak_37.txt 0.142
# 105 perjalanan_31.txt 0.142
# 106 pengusaha_dan_bisnis_70.txt 0.141
# 107 pengusaha_dan_bisnis_74.txt 0.141
# 108 guru_dan_siswa_27.txt 0.141
# 109 ibu_dan_anak_3.txt 0.14
# 110 perjalanan_20.txt 0.14
# 111 guru_dan_siswa_21.txt 0.14
# 112 perjalanan_76.txt 0.139
# 113 ibu_dan_anak_40.txt 0.139
# 114 pengusaha_dan_bisnis_38.txt 0.138
# 115 ibu_dan_anak_25.txt 0.138
# 116 perjalanan_7.txt 0.138
# 117 guru_dan_siswa_11.txt 0.137
# 118 ibu_dan_anak_8.txt 0.137
# 119 tokoh_agama_dan_masyarakat_56.txt 0.137
# 120 pengusaha_dan_bisnis_27.txt 0.136
# 121 ibu_dan_anak_12.txt 0.135
# 122 perjalanan_95.txt 0.135
# 123 perjalanan_38.txt 0.134
# 124 pengusaha_dan_bisnis_64.txt 0.133
# 125 ibu_dan_anak_27.txt 0.132
# 126 perjalanan_67.txt 0.13
# 127 tokoh_agama_dan_masyarakat_39.txt 0.13
# 128 tokoh_agama_dan_masyarakat_17.txt 0.129
# 129 guru_dan_siswa_29.txt 0.129
# 130 guru_dan_siswa_14.txt 0.129
# 131 perjalanan_49.txt 0.129
# 132 pengusaha_dan_bisnis_88.txt 0.129
# 133 pengusaha_dan_bisnis_90.txt 0.128
# 134 guru_dan_siswa_32.txt 0.128
# 135 pengusaha_dan_bisnis_23.txt 0.127
# 136 ibu_dan_anak_23.txt 0.126
# 137 pengusaha_dan_bisnis_58.txt 0.126
# 138 guru_dan_siswa_62.txt 0.126
# 139 pengusaha_dan_bisnis_53.txt 0.126
# 140 pengusaha_dan_bisnis_67.txt 0.125
# 141 pengusaha_dan_bisnis_76.txt 0.125
# 142 tokoh_agama_dan_masyarakat_66.txt 0.124
# 143 guru_dan_siswa_43.txt 0.124
# 144 ibu_dan_anak_62.txt 0.123
# 145 pengusaha_dan_bisnis_46.txt 0.123
# 146 guru_dan_siswa_6.txt 0.123
# 147 pengusaha_dan_bisnis_33.txt 0.122
# 148 guru_dan_siswa_7.txt 0.122
# 149 pengusaha_dan_bisnis_25.txt 0.122
# 150 guru_dan_siswa_61.txt 0.121
# 151 ibu_dan_anak_26.txt 0.12
# 152 guru_dan_siswa_8.txt 0.12
# 153 tokoh_agama_dan_masyarakat_42.txt 0.12
# 154 perjalanan_30.txt 0.12
# 155 tokoh_agama_dan_masyarakat_44.txt 0.12
# 156 pengusaha_dan_bisnis_8.txt 0.12
# 157 pengusaha_dan_bisnis_26.txt 0.12
# 158 perjalanan_59.txt 0.119
# 159 perjalanan_77.txt 0.119
# 160 tokoh_agama_dan_masyarakat_67.txt 0.119
# 161 pengusaha_dan_bisnis_60.txt 0.119
# 162 pengusaha_dan_bisnis_86.txt 0.119
# 163 guru_dan_siswa_38.txt 0.117
# 164 pengusaha_dan_bisnis_28.txt 0.117
# 165 ibu_dan_anak_44.txt 0.117
# 166 tokoh_agama_dan_masyarakat_26.txt 0.117
# 167 pengusaha_dan_bisnis_103.txt 0.116
# 168 ibu_dan_anak_19.txt 0.115
# 169 ibu_dan_anak_54.txt 0.115
# 170 tokoh_agama_dan_masyarakat_3.txt 0.114
# 171 ibu_dan_anak_22.txt 0.112
# 172 perjalanan_12.txt 0.112
# 173 perjalanan_14.txt 0.112
# 174 pengusaha_dan_bisnis_16.txt 0.111
# 175 pengusaha_dan_bisnis_89.txt 0.111
# 176 tokoh_agama_dan_masyarakat_54.txt 0.111
# 177 perjalanan_74.txt 0.11
# 178 perjalanan_104.txt 0.109
# 179 guru_dan_siswa_28.txt 0.109
# 180 tokoh_agama_dan_masyarakat_15.txt 0.108
# 181 ibu_dan_anak_20.txt 0.108
# 182 perjalanan_39.txt 0.108
# 183 guru_dan_siswa_63.txt 0.108
# 184 perjalanan_40.txt 0.108
# 185 pengusaha_dan_bisnis_2.txt 0.107
# 186 guru_dan_siswa_19.txt 0.107
# 187 perjalanan_62.txt 0.106
# 188 guru_dan_siswa_40.txt 0.106
# 189 ibu_dan_anak_38.txt 0.106
# 190 tokoh_agama_dan_masyarakat_48.txt 0.105
# 191 perjalanan_83.txt 0.105
# 192 guru_dan_siswa_51.txt 0.104
# 193 tokoh_agama_dan_masyarakat_10.txt 0.103
# 194 tokoh_agama_dan_masyarakat_40.txt 0.103
# 195 guru_dan_siswa_46.txt 0.103
# 196 perjalanan_81.txt 0.103
# 197 pengusaha_dan_bisnis_98.txt 0.102
# 198 pengusaha_dan_bisnis_62.txt 0.101
# 199 guru_dan_siswa_31.txt 0.101
# 200 pengusaha_dan_bisnis_102.txt 0.1
# 201 ibu_dan_anak_29.txt 0.1
